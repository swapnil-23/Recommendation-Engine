# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
## reading the dataset

books = pd.read_csv('D:\MY PROJECTS(AI-ML-DATA SCIENCE)\RECOMMENDATION ENGINES\BX-Books.csv', sep=';', error_bad_lines=False, encoding="latin-1")
books.columns = ['ISBN', 'bookTitle', 'bookAuthor', 'yearOfPublication', 'publisher', 'imageUrlS', 'imageUrlM', 'imageUrlL']
users = pd.read_csv('D:\MY PROJECTS(AI-ML-DATA SCIENCE)\RECOMMENDATION ENGINES\BX-Users.csv', sep=';', error_bad_lines=False, encoding="latin-1")
users.columns = ['userID', 'Location', 'Age']
ratings = pd.read_csv('BX-Book-Ratings.csv', sep=';', error_bad_lines=False, encoding="latin-1")
ratings.columns = ['userID', 'ISBN', 'bookRating']
# Out:
# C:\Users\SWAPNIL BISWAS\AppData\Local\Temp\ipykernel_10888\1478134848.py:3: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   books = pd.read_csv('D:\MY PROJECTS(AI-ML-DATA SCIENCE)\RECOMMENDATION ENGINES\BX-Books.csv', sep=';', error_bad_lines=False, encoding="latin-1")
# Skipping line 6452: expected 8 fields, saw 9
# Skipping line 43667: expected 8 fields, saw 10
# Skipping line 51751: expected 8 fields, saw 9
#
# Skipping line 92038: expected 8 fields, saw 9
# Skipping line 104319: expected 8 fields, saw 9
# Skipping line 121768: expected 8 fields, saw 9
#
# Skipping line 144058: expected 8 fields, saw 9
# Skipping line 150789: expected 8 fields, saw 9
# Skipping line 157128: expected 8 fields, saw 9
# Skipping line 180189: expected 8 fields, saw 9
# Skipping line 185738: expected 8 fields, saw 9
#
# Skipping line 209388: expected 8 fields, saw 9
# ...

# %%
print(ratings.shape)
print(ratings.columns)
# Out:
# (1149780, 3)
# Index(['userID', 'ISBN', 'bookRating'], dtype='object')

# %%
print(books.shape)
print(books.columns)
# Out:
# (271360, 8)
# Index(['ISBN', 'bookTitle', 'bookAuthor', 'yearOfPublication', 'publisher',
#        'imageUrlS', 'imageUrlM', 'imageUrlL'],
#       dtype='object')

# %%
print(users.shape)
print(users.columns)
# Out:
# (278858, 3)
# Index(['userID', 'Location', 'Age'], dtype='object')

# %%
rating_count = pd.DataFrame(ratings.groupby('ISBN')['bookRating'].count())
rating_count.sort_values('bookRating', ascending=False).head(10)
# Out:
#             bookRating
# ISBN
# 0971880107        2502
# 0316666343        1295
# 0385504209         883
# 0060928336         732
# 0312195516         723
# 044023722X         647
# 0679781587         639
# 0142001740         615
# 067976402X         614
# 0671027360         586

# %%
## creating the recommendation based on the ratings
most_rated = pd.DataFrame(['0971880107', '0316666343', '0385504209', '0060928336', '0312195516'], index = np.arange(5), columns=['ISBN'])
most_rated_summary = pd.merge(most_rated, books, on='ISBN')
most_rated_summary
# Out:
#          ISBN                                        bookTitle     bookAuthor  \
# 0  0971880107                                      Wild Animus   Rich Shapero
# 1  0316666343                        The Lovely Bones: A Novel   Alice Sebold
# 2  0385504209                                The Da Vinci Code      Dan Brown
# 3  0060928336  Divine Secrets of the Ya-Ya Sisterhood: A Novel  Rebecca Wells
# 4  0312195516              The Red Tent (Bestselling Backlist)  Anita Diamant
#
#   yearOfPublication      publisher  \
# 0              2004        Too Far
# 1              2002  Little, Brown
# 2              2003      Doubleday
# 3              1997      Perennial
# 4              1998    Picador USA
#
#                                            imageUrlS  \
# 0  http://images.amazon.com/images/P/0971880107.0...
# 1  http://images.amazon.com/images/P/0316666343.0...
# 2  http://images.amazon.com/images/P/0385504209.0...
# 3  http://images.amazon.com/images/P/0060928336.0...
# ...

# %%
## creating recommendations based on correlations

avg_rating = pd.DataFrame(ratings.groupby('ISBN')['bookRating'].mean())
avg_rating['ratingCount'] = pd.DataFrame(ratings.groupby('ISBN')['bookRating'].count())
avg_rating.sort_values('ratingCount', ascending=False).head(10)
# Out:
#             bookRating  ratingCount
# ISBN
# 0971880107    1.019584         2502
# 0316666343    4.468726         1295
# 0385504209    4.652322          883
# 0060928336    3.448087          732
# 0312195516    4.334716          723
# 044023722X    3.187017          647
# 0679781587    4.381847          639
# 0142001740    4.219512          615
# 067976402X    3.255700          614
# 0671027360    3.718430          586

# %%
counts1 = ratings['userID'].value_counts()
ratings = ratings[ratings['userID'].isin(counts1[counts1 >= 200].index)]
counts = ratings['bookRating'].value_counts()
ratings = ratings[ratings['bookRating'].isin(counts[counts >= 100].index)]

# %%
ratings_pivot = ratings.pivot(index='userID', columns='ISBN').bookRating
userID = ratings_pivot.index
ISBN = ratings_pivot.columns
print(ratings_pivot.shape)
ratings_pivot.head()
# Out:
# (905, 207699)
# ISBN     0330299891   0375404120   0586045007   9022906116   9032803328  \
# userID
# 254             NaN          NaN          NaN          NaN          NaN
# 2276            NaN          NaN          NaN          NaN          NaN
# 2766            NaN          NaN          NaN          NaN          NaN
# 2977            NaN          NaN          NaN          NaN          NaN
# 3363            NaN          NaN          NaN          NaN          NaN
#
# ISBN     9044922564   9044922572   9044922718   9044923161   904492401X  ...  \
# userID                                                                   ...
# 254             NaN          NaN          NaN          NaN          NaN  ...
# 2276            NaN          NaN          NaN          NaN          NaN  ...
# 2766            NaN          NaN          NaN          NaN          NaN  ...
# 2977            NaN          NaN          NaN          NaN          NaN  ...
# ...

# %%
X_rating = ratings_pivot['0375404120']
similar_to_X = ratings_pivot.corrwith(X_rating)
corr_X = pd.DataFrame(similar_to_X, columns=['pearsonR'])
corr_X.dropna(inplace=True)
corr_summary = corr_X.join(avg_rating['ratingCount'])
corr_summary[corr_summary['ratingCount']>=300].sort_values('pearsonR', ascending=False).head(10)
# Out:
# d:\SCAAI\project\lib\site-packages\numpy\lib\function_base.py:2846: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar, dtype=dtype)
# d:\SCAAI\project\lib\site-packages\numpy\lib\function_base.py:2705: RuntimeWarning: divide by zero encountered in divide
#   c *= np.true_divide(1, fact)
#             pearsonR  ratingCount
# ISBN
# 0440211727       1.0          517
# 0671003755       1.0          446
# 0316666343       0.5         1295
# 0060987103      -1.0          326
